# %% [markdown]
# <a href="https://colab.research.google.com/github/aasher-57020/Portfolio-Project/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AND Gate

# %%
#and
from sklearn.linear_model import Perceptron
x_train=[[0,0],[0,1],[1,0],[1,1]]
y_train=[0,0,0,1]

clf=Perceptron(tol=1e-3, random_state=0)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_train)
print(y_pred)
print(clf.coef_,clf.intercept_)
# Out:
# [0 0 0 1]
# [[2. 2.]] [-2.]

# %% [markdown]
# **OR Gate**

# %%
#or
from sklearn.linear_model import Perceptron
x_train=[[0,0],[0,1],[1,0],[1,1]]
y_train=[0,1,1,1]

clf=Perceptron(tol=1e-3, random_state=0)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_train)
print(y_pred)
print(clf.coef_,clf.intercept_)
# Out:
# [0 1 1 1]
# [[2. 2.]] [-1.]

# %% [markdown]
# **NAND Gate**

# %%
#nand
from sklearn.linear_model import Perceptron
x_train=[[0,0],[0,1],[1,0],[1,1]]
y_train=[1,1,1,0]

clf=Perceptron(tol=1e-3, random_state=42)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_train)
print(y_pred)
print(clf.coef_,clf.intercept_)
# Out:
# [1 1 1 0]
# [[-2. -2.]] [3.]

# %% [markdown]
# **XNOR Gate**

# %%
#xnor
from sklearn.linear_model import Perceptron
x1_train=[[0,0],[0,1]]
y1_train=[1,0]
x2_train=[[1,0],[1,1]]
y2_train=[0,1]

clf1=Perceptron(tol=1e-2, random_state=0)
clf1.fit(x1_train,y1_train)

clf2=Perceptron(tol=1e+3, random_state=0)
clf2.fit(x2_train,y2_train)

y1_pred=clf1.predict(x1_train)
print(y1_pred)

y2_pred=clf2.predict(x2_train)
print(y2_pred)

print(clf1.coef_,clf1.intercept_)
print(clf2.coef_,clf2.intercept_)
# Out:
# [1 0]
# [0 1]
# [[ 0. -2.]] [1.]
# [[-1.  3.]] [-1.]

# %% [markdown]
# **XOR Gate**

# %%
#xor
from sklearn.linear_model import Perceptron
x1_train=[[0,0],[0,1]]
y1_train=[0,1]
x2_train=[[1,0],[1,1]]
y2_train=[1,0]

clf1=Perceptron(tol=1e-2, random_state=0)
clf1.fit(x1_train,y1_train)

clf2=Perceptron(tol=1e+3, random_state=0)
clf2.fit(x2_train,y2_train)

y1_pred=clf1.predict(x1_train)
print(y1_pred)

y2_pred=clf2.predict(x2_train)
print(y2_pred)

print(clf1.coef_,clf1.intercept_)
print(clf2.coef_,clf2.intercept_)
# Out:
# [0 1]
# [1 0]
# [[0. 2.]] [-1.]
# [[ 1. -3.]] [1.]

# %% [markdown]
# Predicting

# %%
from sklearn.neural_network import MLPClassifier
x_train=[[165,52],[153,50],[160,48],[177,72],[185,68],[174,85],[170,60],[165,58]]
y_train=[0,0,0,1,1,1,1,1]

clf=MLPClassifier(solver='adam',alpha=1e-5,activation='relu',hidden_layer_sizes=(120),random_state=1)

clf.fit(x_train,y_train)
y_pred=clf.predict([[170,55]])
print(y_pred)
# Out:
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import numpy as np
from matplotlib import pyplot as plt

x=np.array(x_train)

plt.scatter(x[:4,0],x[:4,1])
plt.scatter(x[4:,0],x[4:,1])
plt.show()
